# %%
import pandas as pd

# %%
df=pd.read_csv("files_for_lab/csv_files/marketing_customer_analysis.csv",sep=",")

# %%
df
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0         Basic   College           2/18/11         Employed      M  ...
# 1         Basic   College           1/18/11       Unemployed      F  ...
# 2         Basic  Bachelor           2/10/11         Employed      M  ...
# 3      Extended   College           1/11/11         Employed      M  ...
# 4       Premium  Bachelor           1/17/11    Medical Leave      F  ...
# ...         ...       ...               ...              ...    ...  ...
# 10905   Premium  Bachelor           1/19/11       Unemployed      F  ...
# 10906     Basic   College            1/6/11         Employed      F  ...
# 10907  Extended  Bachelor            2/6/11         Employed      F  ...
# 10908   Premium   College           2/13/11         Employed      F  ...
# 10909     Basic  Bachelor            1/8/11       Unemployed      M  ...
#
#        Number of Open Complaints Number of Policies     Policy Type  \
# 0                            0.0                  9  Corporate Auto
# 1                            0.0                  1   Personal Auto
# 2                            0.0                  2   Personal Auto
# 3                            0.0                  2  Corporate Auto
# 4                            NaN                  7   Personal Auto
# ...                          ...                ...             ...
# 10905                        NaN                  7   Personal Auto
# 10906                        0.0                  6   Personal Auto
# 10907                        0.0                  2  Corporate Auto
# 10908                        4.0                  6   Personal Auto
# 10909                        0.0                  3   Personal Auto
#
#              Policy  Renew Offer Type  Sales Channel  Total Claim Amount  \
# 0      Corporate L3            Offer3          Agent          292.800000
# 1       Personal L3            Offer4    Call Center          744.924331
# 2       Personal L3            Offer3    Call Center          480.000000
# 3      Corporate L3            Offer2         Branch          484.013411
# 4       Personal L2            Offer1         Branch          707.925645
# ...             ...               ...            ...                 ...
# 10905   Personal L1            Offer3            Web         1214.400000
# 10906   Personal L3            Offer2         Branch          273.018929
# 10907  Corporate L3            Offer1            Web          381.306996
# 10908   Personal L1            Offer1         Branch          618.288849
# 10909   Personal L1            Offer4            Web         1021.719397
#
#        Vehicle Class Vehicle Size Vehicle Type
# 0      Four-Door Car      Medsize          NaN
# 1      Four-Door Car      Medsize          NaN
# 2                SUV      Medsize            A
# 3      Four-Door Car      Medsize            A
# 4      Four-Door Car      Medsize          NaN
# ...              ...          ...          ...
# 10905     Luxury Car      Medsize            A
# 10906  Four-Door Car      Medsize            A
# 10907     Luxury SUV      Medsize          NaN
# 10908            SUV      Medsize            A
# 10909            SUV      Medsize          NaN
#
# [10910 rows x 26 columns]

# %%
df.size
# Out:
# 283660

# %%
col1=[col_name.lower().replace(" ","_") for col_name in df.columns]

# %%
col1
# Out:
# ['unnamed:_0',
#  'customer',
#  'state',
#  'customer_lifetime_value',
#  'response',
#  'coverage',
#  'education',
#  'effective_to_date',
#  'employmentstatus',
#  'gender',
#  'income',
#  'location_code',
#  'marital_status',
#  'monthly_premium_auto',
#  'months_since_last_claim',
#  'months_since_policy_inception',
#  'number_of_open_complaints',
#  'number_of_policies',
#  'policy_type',
#  'policy',
#  'renew_offer_type',
#  'sales_channel',
#  'total_claim_amount',
#  'vehicle_class',
#  'vehicle_size',
#  'vehicle_type']

# %%
df.columns=col1

# %%
df
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# 0         Basic   College           2/18/11         Employed      M  ...
# 1         Basic   College           1/18/11       Unemployed      F  ...
# 2         Basic  Bachelor           2/10/11         Employed      M  ...
# 3      Extended   College           1/11/11         Employed      M  ...
# 4       Premium  Bachelor           1/17/11    Medical Leave      F  ...
# ...         ...       ...               ...              ...    ...  ...
# 10905   Premium  Bachelor           1/19/11       Unemployed      F  ...
# 10906     Basic   College            1/6/11         Employed      F  ...
# 10907  Extended  Bachelor            2/6/11         Employed      F  ...
# 10908   Premium   College           2/13/11         Employed      F  ...
# 10909     Basic  Bachelor            1/8/11       Unemployed      M  ...
#
#        number_of_open_complaints number_of_policies     policy_type  \
# 0                            0.0                  9  Corporate Auto
# 1                            0.0                  1   Personal Auto
# 2                            0.0                  2   Personal Auto
# 3                            0.0                  2  Corporate Auto
# 4                            NaN                  7   Personal Auto
# ...                          ...                ...             ...
# 10905                        NaN                  7   Personal Auto
# 10906                        0.0                  6   Personal Auto
# 10907                        0.0                  2  Corporate Auto
# 10908                        4.0                  6   Personal Auto
# 10909                        0.0                  3   Personal Auto
#
#              policy  renew_offer_type  sales_channel  total_claim_amount  \
# 0      Corporate L3            Offer3          Agent          292.800000
# 1       Personal L3            Offer4    Call Center          744.924331
# 2       Personal L3            Offer3    Call Center          480.000000
# 3      Corporate L3            Offer2         Branch          484.013411
# 4       Personal L2            Offer1         Branch          707.925645
# ...             ...               ...            ...                 ...
# 10905   Personal L1            Offer3            Web         1214.400000
# 10906   Personal L3            Offer2         Branch          273.018929
# 10907  Corporate L3            Offer1            Web          381.306996
# 10908   Personal L1            Offer1         Branch          618.288849
# 10909   Personal L1            Offer4            Web         1021.719397
#
#        vehicle_class vehicle_size vehicle_type
# 0      Four-Door Car      Medsize          NaN
# 1      Four-Door Car      Medsize          NaN
# 2                SUV      Medsize            A
# 3      Four-Door Car      Medsize            A
# 4      Four-Door Car      Medsize          NaN
# ...              ...          ...          ...
# 10905     Luxury Car      Medsize            A
# 10906  Four-Door Car      Medsize            A
# 10907     Luxury SUV      Medsize          NaN
# 10908            SUV      Medsize            A
# 10909            SUV      Medsize          NaN
#
# [10910 rows x 26 columns]

# %%
col=df.columns
col
for c in col:
    if df[c].dtypes=="<f8":
        print (c)
# Out:
# customer_lifetime_value
# months_since_last_claim
# number_of_open_complaints
# total_claim_amount

# %%
col=df.columns
col
for c in col:
    if df[c].dtypes=="|O":
        print (c)
# Out:
# customer
# state
# response
# coverage
# education
# effective_to_date
# employmentstatus
# gender
# location_code
# marital_status
# policy_type
# policy
# renew_offer_type
# sales_channel
# vehicle_class
# vehicle_size
# vehicle_type

# %%
df.isna().sum()
# Out:
# unnamed:_0                          0
# customer                            0
# state                             631
# customer_lifetime_value             0
# response                          631
# coverage                            0
# education                           0
# effective_to_date                   0
# employmentstatus                    0
# gender                              0
# income                              0
# location_code                       0
# marital_status                      0
# monthly_premium_auto                0
# months_since_last_claim           633
# months_since_policy_inception       0
# number_of_open_complaints         633
# number_of_policies                  0
# policy_type                         0
# policy                              0
# renew_offer_type                    0
# sales_channel                       0
# total_claim_amount                  0
# vehicle_class                     622
# vehicle_size                      622
# vehicle_type                     5482
# dtype: int64

# %%
df= df.dropna(subset=["state","response","vehicle_class","vehicle_size"])

# %%
df.isna().sum()
# Out:
# unnamed:_0                          0
# customer                            0
# state                               0
# customer_lifetime_value             0
# response                            0
# coverage                            0
# education                           0
# effective_to_date                   0
# employmentstatus                    0
# gender                              0
# income                              0
# location_code                       0
# marital_status                      0
# monthly_premium_auto                0
# months_since_last_claim           554
# months_since_policy_inception       0
# number_of_open_complaints         554
# number_of_policies                  0
# policy_type                         0
# policy                              0
# renew_offer_type                    0
# sales_channel                       0
# total_claim_amount                  0
# vehicle_class                       0
# vehicle_size                        0
# vehicle_type                     4869
# dtype: int64

# %%
df["vehicle_type"]=df['vehicle_type'].fillna("")
# Out:
# C:\Users\aci\AppData\Local\Temp\ipykernel_32896\2174020436.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["vehicle_type"]=df['vehicle_type'].fillna("")

# %%
df.isna().sum()
# Out:
# unnamed:_0                         0
# customer                           0
# state                              0
# customer_lifetime_value            0
# response                           0
# coverage                           0
# education                          0
# effective_to_date                  0
# employmentstatus                   0
# gender                             0
# income                             0
# location_code                      0
# marital_status                     0
# monthly_premium_auto               0
# months_since_last_claim          554
# months_since_policy_inception      0
# number_of_open_complaints        554
# number_of_policies                 0
# policy_type                        0
# policy                             0
# renew_offer_type                   0
# sales_channel                      0
# total_claim_amount                 0
# vehicle_class                      0
# vehicle_size                       0
# vehicle_type                       0
# dtype: int64

# %%
col_median=df["months_since_last_claim"].median()

# %%
df["months_since_last_claim"]=df["months_since_last_claim"].fillna(col_median)
# Out:
# C:\Users\aci\AppData\Local\Temp\ipykernel_32896\894665933.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["months_since_last_claim"]=df["months_since_last_claim"].fillna(col_median)

# %%
df.isna().sum()
# Out:
# unnamed:_0                         0
# customer                           0
# state                              0
# customer_lifetime_value            0
# response                           0
# coverage                           0
# education                          0
# effective_to_date                  0
# employmentstatus                   0
# gender                             0
# income                             0
# location_code                      0
# marital_status                     0
# monthly_premium_auto               0
# months_since_last_claim            0
# months_since_policy_inception      0
# number_of_open_complaints        554
# number_of_policies                 0
# policy_type                        0
# policy                             0
# renew_offer_type                   0
# sales_channel                      0
# total_claim_amount                 0
# vehicle_class                      0
# vehicle_size                       0
# vehicle_type                       0
# dtype: int64

# %%
col_median2=df["number_of_open_complaints"].median()

# %%
df["number_of_open_complaints"]=df["number_of_open_complaints"].fillna(col_median2)
# Out:
# C:\Users\aci\AppData\Local\Temp\ipykernel_32896\234347473.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["number_of_open_complaints"]=df["number_of_open_complaints"].fillna(col_median2)

# %%
df.isna().sum()
# Out:
# unnamed:_0                       0
# customer                         0
# state                            0
# customer_lifetime_value          0
# response                         0
# coverage                         0
# education                        0
# effective_to_date                0
# employmentstatus                 0
# gender                           0
# income                           0
# location_code                    0
# marital_status                   0
# monthly_premium_auto             0
# months_since_last_claim          0
# months_since_policy_inception    0
# number_of_open_complaints        0
# number_of_policies               0
# policy_type                      0
# policy                           0
# renew_offer_type                 0
# sales_channel                    0
# total_claim_amount               0
# vehicle_class                    0
# vehicle_size                     0
# vehicle_type                     0
# dtype: int64

# %%
df
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10904       10904  QI63521      Nevada             19228.463620       No
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
#
#        coverage             education effective_to_date employmentstatus  \
# 0         Basic               College           2/18/11         Employed
# 1         Basic               College           1/18/11       Unemployed
# 2         Basic              Bachelor           2/10/11         Employed
# 3      Extended               College           1/11/11         Employed
# 4       Premium              Bachelor           1/17/11    Medical Leave
# ...         ...                   ...               ...              ...
# 10904     Basic  High School or Below           2/24/11       Unemployed
# 10905   Premium              Bachelor           1/19/11       Unemployed
# 10906     Basic               College            1/6/11         Employed
# 10907  Extended              Bachelor            2/6/11         Employed
# 10908   Premium               College           2/13/11         Employed
#
#       gender  ...  number_of_open_complaints number_of_policies  \
# 0          M  ...                        0.0                  9
# 1          F  ...                        0.0                  1
# 2          M  ...                        0.0                  2
# 3          M  ...                        0.0                  2
# 4          F  ...                        0.0                  7
# ...      ...  ...                        ...                ...
# 10904      M  ...                        0.0                  2
# 10905      F  ...                        0.0                  7
# 10906      F  ...                        0.0                  6
# 10907      F  ...                        0.0                  2
# 10908      F  ...                        4.0                  6
#
#           policy_type        policy  renew_offer_type  sales_channel  \
# 0      Corporate Auto  Corporate L3            Offer3          Agent
# 1       Personal Auto   Personal L3            Offer4    Call Center
# 2       Personal Auto   Personal L3            Offer3    Call Center
# 3      Corporate Auto  Corporate L3            Offer2         Branch
# 4       Personal Auto   Personal L2            Offer1         Branch
# ...               ...           ...               ...            ...
# 10904   Personal Auto   Personal L2            Offer1         Branch
# 10905   Personal Auto   Personal L1            Offer3            Web
# 10906   Personal Auto   Personal L3            Offer2         Branch
# 10907  Corporate Auto  Corporate L3            Offer1            Web
# 10908   Personal Auto   Personal L1            Offer1         Branch
#
#        total_claim_amount  vehicle_class vehicle_size vehicle_type
# 0              292.800000  Four-Door Car      Medsize
# 1              744.924331  Four-Door Car      Medsize
# 2              480.000000            SUV      Medsize            A
# 3              484.013411  Four-Door Car      Medsize            A
# 4              707.925645  Four-Door Car      Medsize
# ...                   ...            ...          ...          ...
# 10904          897.600000     Luxury SUV      Medsize            A
# 10905         1214.400000     Luxury Car      Medsize            A
# 10906          273.018929  Four-Door Car      Medsize            A
# 10907          381.306996     Luxury SUV      Medsize
# 10908          618.288849            SUV      Medsize            A
#
# [9688 rows x 26 columns]

# %%
df["effective_to_date"]
# Out:
# 0        2/18/11
# 1        1/18/11
# 2        2/10/11
# 3        1/11/11
# 4        1/17/11
#           ...
# 10904    2/24/11
# 10905    1/19/11
# 10906     1/6/11
# 10907     2/6/11
# 10908    2/13/11
# Name: effective_to_date, Length: 9688, dtype: object

# %%
df["effective_to_date"]=pd.to_datetime(df["effective_to_date"])
# Out:
# C:\Users\aci\AppData\Local\Temp\ipykernel_32896\2738640175.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["effective_to_date"]=pd.to_datetime(df["effective_to_date"])

# %%
df
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10904       10904  QI63521      Nevada             19228.463620       No
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
#
#        coverage             education effective_to_date employmentstatus  \
# 0         Basic               College        2011-02-18         Employed
# 1         Basic               College        2011-01-18       Unemployed
# 2         Basic              Bachelor        2011-02-10         Employed
# 3      Extended               College        2011-01-11         Employed
# 4       Premium              Bachelor        2011-01-17    Medical Leave
# ...         ...                   ...               ...              ...
# 10904     Basic  High School or Below        2011-02-24       Unemployed
# 10905   Premium              Bachelor        2011-01-19       Unemployed
# 10906     Basic               College        2011-01-06         Employed
# 10907  Extended              Bachelor        2011-02-06         Employed
# 10908   Premium               College        2011-02-13         Employed
#
#       gender  ...  number_of_open_complaints number_of_policies  \
# 0          M  ...                        0.0                  9
# 1          F  ...                        0.0                  1
# 2          M  ...                        0.0                  2
# 3          M  ...                        0.0                  2
# 4          F  ...                        0.0                  7
# ...      ...  ...                        ...                ...
# 10904      M  ...                        0.0                  2
# 10905      F  ...                        0.0                  7
# 10906      F  ...                        0.0                  6
# 10907      F  ...                        0.0                  2
# 10908      F  ...                        4.0                  6
#
#           policy_type        policy  renew_offer_type  sales_channel  \
# 0      Corporate Auto  Corporate L3            Offer3          Agent
# 1       Personal Auto   Personal L3            Offer4    Call Center
# 2       Personal Auto   Personal L3            Offer3    Call Center
# 3      Corporate Auto  Corporate L3            Offer2         Branch
# 4       Personal Auto   Personal L2            Offer1         Branch
# ...               ...           ...               ...            ...
# 10904   Personal Auto   Personal L2            Offer1         Branch
# 10905   Personal Auto   Personal L1            Offer3            Web
# 10906   Personal Auto   Personal L3            Offer2         Branch
# 10907  Corporate Auto  Corporate L3            Offer1            Web
# 10908   Personal Auto   Personal L1            Offer1         Branch
#
#        total_claim_amount  vehicle_class vehicle_size vehicle_type
# 0              292.800000  Four-Door Car      Medsize
# 1              744.924331  Four-Door Car      Medsize
# 2              480.000000            SUV      Medsize            A
# 3              484.013411  Four-Door Car      Medsize            A
# 4              707.925645  Four-Door Car      Medsize
# ...                   ...            ...          ...          ...
# 10904          897.600000     Luxury SUV      Medsize            A
# 10905         1214.400000     Luxury Car      Medsize            A
# 10906          273.018929  Four-Door Car      Medsize            A
# 10907          381.306996     Luxury SUV      Medsize
# 10908          618.288849            SUV      Medsize            A
#
# [9688 rows x 26 columns]

# %%
df["month"]=df["effective_to_date"].dt.month
# Out:
# C:\Users\aci\AppData\Local\Temp\ipykernel_32896\1933767332.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["month"]=df["effective_to_date"].dt.month

# %%
df
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10904       10904  QI63521      Nevada             19228.463620       No
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
#
#        coverage             education effective_to_date employmentstatus  \
# 0         Basic               College        2011-02-18         Employed
# 1         Basic               College        2011-01-18       Unemployed
# 2         Basic              Bachelor        2011-02-10         Employed
# 3      Extended               College        2011-01-11         Employed
# 4       Premium              Bachelor        2011-01-17    Medical Leave
# ...         ...                   ...               ...              ...
# 10904     Basic  High School or Below        2011-02-24       Unemployed
# 10905   Premium              Bachelor        2011-01-19       Unemployed
# 10906     Basic               College        2011-01-06         Employed
# 10907  Extended              Bachelor        2011-02-06         Employed
# 10908   Premium               College        2011-02-13         Employed
#
#       gender  ...  number_of_policies     policy_type        policy  \
# 0          M  ...                   9  Corporate Auto  Corporate L3
# 1          F  ...                   1   Personal Auto   Personal L3
# 2          M  ...                   2   Personal Auto   Personal L3
# 3          M  ...                   2  Corporate Auto  Corporate L3
# 4          F  ...                   7   Personal Auto   Personal L2
# ...      ...  ...                 ...             ...           ...
# 10904      M  ...                   2   Personal Auto   Personal L2
# 10905      F  ...                   7   Personal Auto   Personal L1
# 10906      F  ...                   6   Personal Auto   Personal L3
# 10907      F  ...                   2  Corporate Auto  Corporate L3
# 10908      F  ...                   6   Personal Auto   Personal L1
#
#        renew_offer_type  sales_channel  total_claim_amount  vehicle_class  \
# 0                Offer3          Agent          292.800000  Four-Door Car
# 1                Offer4    Call Center          744.924331  Four-Door Car
# 2                Offer3    Call Center          480.000000            SUV
# 3                Offer2         Branch          484.013411  Four-Door Car
# 4                Offer1         Branch          707.925645  Four-Door Car
# ...                 ...            ...                 ...            ...
# 10904            Offer1         Branch          897.600000     Luxury SUV
# 10905            Offer3            Web         1214.400000     Luxury Car
# 10906            Offer2         Branch          273.018929  Four-Door Car
# 10907            Offer1            Web          381.306996     Luxury SUV
# 10908            Offer1         Branch          618.288849            SUV
#
#        vehicle_size vehicle_type month
# 0           Medsize                  2
# 1           Medsize                  1
# 2           Medsize            A     2
# 3           Medsize            A     1
# 4           Medsize                  1
# ...             ...          ...   ...
# 10904       Medsize            A     2
# 10905       Medsize            A     1
# 10906       Medsize            A     1
# 10907       Medsize                  2
# 10908       Medsize            A     2
#
# [9688 rows x 27 columns]

# %%
filtered_df=df[df["month"]<4]

# %%
filtered_df
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10904       10904  QI63521      Nevada             19228.463620       No
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
#
#        coverage             education effective_to_date employmentstatus  \
# 0         Basic               College        2011-02-18         Employed
# 1         Basic               College        2011-01-18       Unemployed
# 2         Basic              Bachelor        2011-02-10         Employed
# 3      Extended               College        2011-01-11         Employed
# 4       Premium              Bachelor        2011-01-17    Medical Leave
# ...         ...                   ...               ...              ...
# 10904     Basic  High School or Below        2011-02-24       Unemployed
# 10905   Premium              Bachelor        2011-01-19       Unemployed
# 10906     Basic               College        2011-01-06         Employed
# 10907  Extended              Bachelor        2011-02-06         Employed
# 10908   Premium               College        2011-02-13         Employed
#
#       gender  ...  number_of_policies     policy_type        policy  \
# 0          M  ...                   9  Corporate Auto  Corporate L3
# 1          F  ...                   1   Personal Auto   Personal L3
# 2          M  ...                   2   Personal Auto   Personal L3
# 3          M  ...                   2  Corporate Auto  Corporate L3
# 4          F  ...                   7   Personal Auto   Personal L2
# ...      ...  ...                 ...             ...           ...
# 10904      M  ...                   2   Personal Auto   Personal L2
# 10905      F  ...                   7   Personal Auto   Personal L1
# 10906      F  ...                   6   Personal Auto   Personal L3
# 10907      F  ...                   2  Corporate Auto  Corporate L3
# 10908      F  ...                   6   Personal Auto   Personal L1
#
#        renew_offer_type  sales_channel  total_claim_amount  vehicle_class  \
# 0                Offer3          Agent          292.800000  Four-Door Car
# 1                Offer4    Call Center          744.924331  Four-Door Car
# 2                Offer3    Call Center          480.000000            SUV
# 3                Offer2         Branch          484.013411  Four-Door Car
# 4                Offer1         Branch          707.925645  Four-Door Car
# ...                 ...            ...                 ...            ...
# 10904            Offer1         Branch          897.600000     Luxury SUV
# 10905            Offer3            Web         1214.400000     Luxury Car
# 10906            Offer2         Branch          273.018929  Four-Door Car
# 10907            Offer1            Web          381.306996     Luxury SUV
# 10908            Offer1         Branch          618.288849            SUV
#
#        vehicle_size vehicle_type month
# 0           Medsize                  2
# 1           Medsize                  1
# 2           Medsize            A     2
# 3           Medsize            A     1
# 4           Medsize                  1
# ...             ...          ...   ...
# 10904       Medsize            A     2
# 10905       Medsize            A     1
# 10906       Medsize            A     1
# 10907       Medsize                  2
# 10908       Medsize            A     2
#
# [9688 rows x 27 columns]

# %%
df.sort_values("month", ascending=False)
# Out:
#       unnamed:_0 customer       state  customer_lifetime_value response  \
# 0              0  DK49336     Arizona              4809.216960       No
# 6089        6089  DQ34772     Arizona              6361.845408       No
# 6036        6036  DZ62350  California              2514.282096       No
# 6035        6035  EW82164  California              4167.419574       No
# 6033        6033  NC63295     Arizona              2444.621056       No
# ...          ...      ...         ...                      ...      ...
# 6286        6286  OS94884     Arizona              7649.281990       No
# 6285        6285  LO48748      Oregon              7485.356469       No
# 2200        2200  OQ15169  Washington              5597.124960      Yes
# 6281        6281  AE30506  California              2396.219292      Yes
# 7237        7237  MD14027      Nevada              7654.227067       No
#
#       coverage             education effective_to_date employmentstatus  \
# 0        Basic               College        2011-02-18         Employed
# 6089  Extended  High School or Below        2011-02-20       Unemployed
# 6036     Basic  High School or Below        2011-02-07         Employed
# 6035     Basic              Bachelor        2011-02-03         Employed
# 6033     Basic  High School or Below        2011-02-10       Unemployed
# ...        ...                   ...               ...              ...
# 6286     Basic              Bachelor        2011-01-06         Employed
# 6285  Extended                Master        2011-01-30         Employed
# 2200  Extended  High School or Below        2011-01-27         Employed
# 6281     Basic              Bachelor        2011-01-10       Unemployed
# 7237     Basic              Bachelor        2011-01-20       Unemployed
#
#      gender  ...  number_of_policies     policy_type        policy  \
# 0         M  ...                   9  Corporate Auto  Corporate L3
# 6089      M  ...                   4   Personal Auto   Personal L3
# 6036      M  ...                   1   Personal Auto   Personal L3
# 6035      F  ...                   1   Personal Auto   Personal L2
# 6033      M  ...                   1  Corporate Auto  Corporate L2
# ...     ...  ...                 ...             ...           ...
# 6286      F  ...                   2   Personal Auto   Personal L2
# 6285      F  ...                   4   Personal Auto   Personal L1
# 2200      F  ...                   1  Corporate Auto  Corporate L3
# 6281      F  ...                   1   Personal Auto   Personal L3
# 7237      F  ...                   2   Personal Auto   Personal L1
#
#       renew_offer_type  sales_channel  total_claim_amount  vehicle_class  \
# 0               Offer3          Agent          292.800000  Four-Door Car
# 6089            Offer4         Branch          110.527627  Four-Door Car
# 6036            Offer4    Call Center          312.000000  Four-Door Car
# 6035            Offer1          Agent          499.200000            SUV
# 6033            Offer3         Branch          316.800000  Four-Door Car
# ...                ...            ...                 ...            ...
# 6286            Offer1            Web          128.705563   Two-Door Car
# 6285            Offer2            Web          177.369840  Four-Door Car
# 2200            Offer1         Branch          667.200000            SUV
# 6281            Offer2    Call Center          433.160284  Four-Door Car
# 7237            Offer1          Agent          355.200000   Two-Door Car
#
#       vehicle_size vehicle_type month
# 0          Medsize                  2
# 6089       Medsize            A     2
# 6036       Medsize                  2
# 6035         Small                  2
# 6033         Large                  2
# ...            ...          ...   ...
# 6286         Large                  1
# 6285         Large                  1
# 2200       Medsize                  1
# 6281         Large                  1
# 7237       Medsize                  1
#
# [9688 rows x 27 columns]

# %%
def clean_up(data):
    col1=[col_name.lower().replace(" ","_") for col_name in data.columns]
    data.columns=col1
    data= data.dropna(subset=["state","response","vehicle_class","vehicle_size"])
    data["vehicle_type"]=data['vehicle_type'].fillna("")
    col_median=data["months_since_last_claim"].median()
    data["months_since_last_claim"]=data["months_since_last_claim"].fillna(col_median)
    col_median2=data["number_of_open_complaints"].median()
    data["number_of_open_complaints"]=data["number_of_open_complaints"].fillna(col_median2)
    data["effective_to_date"]=pd.to_datetime(data["effective_to_date"])
    data["month"]=data["effective_to_date"].dt.month
    data=data[data["month"]<4]
    return data

# %%
df_func=pd.read_csv("files_for_lab/csv_files/marketing_customer_analysis.csv",sep=",")

# %%
clean_up(df_func)
# Out:
# C:\Users\aci\AppData\Local\Temp\ipykernel_30916\800069160.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["vehicle_type"]=data['vehicle_type'].fillna("")
# C:\Users\aci\AppData\Local\Temp\ipykernel_30916\800069160.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["months_since_last_claim"]=data["months_since_last_claim"].fillna(col_median)
# C:\Users\aci\AppData\Local\Temp\ipykernel_30916\800069160.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["number_of_open_complaints"]=data["number_of_open_complaints"].fillna(col_median2)
# C:\Users\aci\AppData\Local\Temp\ipykernel_30916\800069160.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["effective_to_date"]=pd.to_datetime(data["effective_to_date"])
# C:\Users\aci\AppData\Local\Temp\ipykernel_30916\800069160.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["month"]=data["effective_to_date"].dt.month
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10904       10904  QI63521      Nevada             19228.463620       No
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
#
#        coverage             education effective_to_date employmentstatus  \
# 0         Basic               College        2011-02-18         Employed
# 1         Basic               College        2011-01-18       Unemployed
# 2         Basic              Bachelor        2011-02-10         Employed
# 3      Extended               College        2011-01-11         Employed
# 4       Premium              Bachelor        2011-01-17    Medical Leave
# ...         ...                   ...               ...              ...
# 10904     Basic  High School or Below        2011-02-24       Unemployed
# 10905   Premium              Bachelor        2011-01-19       Unemployed
# 10906     Basic               College        2011-01-06         Employed
# 10907  Extended              Bachelor        2011-02-06         Employed
# 10908   Premium               College        2011-02-13         Employed
#
#       gender  ...  number_of_policies     policy_type        policy  \
# 0          M  ...                   9  Corporate Auto  Corporate L3
# 1          F  ...                   1   Personal Auto   Personal L3
# 2          M  ...                   2   Personal Auto   Personal L3
# 3          M  ...                   2  Corporate Auto  Corporate L3
# 4          F  ...                   7   Personal Auto   Personal L2
# ...      ...  ...                 ...             ...           ...
# 10904      M  ...                   2   Personal Auto   Personal L2
# 10905      F  ...                   7   Personal Auto   Personal L1
# 10906      F  ...                   6   Personal Auto   Personal L3
# 10907      F  ...                   2  Corporate Auto  Corporate L3
# 10908      F  ...                   6   Personal Auto   Personal L1
#
#        renew_offer_type  sales_channel  total_claim_amount  vehicle_class  \
# 0                Offer3          Agent          292.800000  Four-Door Car
# 1                Offer4    Call Center          744.924331  Four-Door Car
# 2                Offer3    Call Center          480.000000            SUV
# 3                Offer2         Branch          484.013411  Four-Door Car
# 4                Offer1         Branch          707.925645  Four-Door Car
# ...                 ...            ...                 ...            ...
# 10904            Offer1         Branch          897.600000     Luxury SUV
# 10905            Offer3            Web         1214.400000     Luxury Car
# 10906            Offer2         Branch          273.018929  Four-Door Car
# 10907            Offer1            Web          381.306996     Luxury SUV
# 10908            Offer1         Branch          618.288849            SUV
#
#        vehicle_size vehicle_type month
# 0           Medsize                  2
# 1           Medsize                  1
# 2           Medsize            A     2
# 3           Medsize            A     1
# 4           Medsize                  1
# ...             ...          ...   ...
# 10904       Medsize            A     2
# 10905       Medsize            A     1
# 10906       Medsize            A     1
# 10907       Medsize                  2
# 10908       Medsize            A     2
#
# [9688 rows x 27 columns]
